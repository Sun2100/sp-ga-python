# %%
#lists
#zero indexed

names = [] #creates empty list

days_of_the_week = ['Mon', 'Tue', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']

colors = list() #using the list constructor, also creates an empty list

#adding to the list
names.append('J') #append = add to the end of the list

print(names)

#add your name to the list
names.append('I')
names.append('G')
names.append('L')
names.append('K')
names.append('A')
#print the list
print(names)
print(len(names)) #or set a variable = len(names) then print that variable

#remove an item from end of list
last_in_list = names.pop()
print(last_in_list)
print(names)

second_in_list = names.pop(1)
print(second_in_list)
print(names)

#insert at any position
names.insert(1, 'R') #(index/position , what you want to insert)
print(names)

#count the occurene of an item in a list

numbers = [1, 3, 5, 3, 4, 5, 3, -1, 5]

number_of_fives = numbers.count(5)
print(number_of_fives) #how many times 5 exist in the list
# Out:
# ['J']
# ['J', 'I', 'G', 'L', 'K', 'A']
# 6
# A
# ['J', 'I', 'G', 'L', 'K']
# I
# ['J', 'G', 'L', 'K']
# ['J', 'R', 'G', 'L', 'K']
# 3

# %%
#dictionaries
#a collection o fkey:value pairs

person = {} #an empty dictionary

city = dict() #also an empty dictionary

car = {'make': 'Toyota', 'model': 'Corolla', 'year': '2020'}

#add an item in a dictionary

person['name'] = 'John' # (string John) key is name , item is 'John'
print(person)

#add age to person, age is 27
person['age'] = 27 #integer 27
print(person)

#explain relationship depict in dictionaries - so the class called person has students named 'name' and 'age'? and the student 'name' holds a 'John' on his shirt?
#the student named 'name' that holds 'John' only exist in classroom person. Follow up Question: Can the student can be borrowed?

#keys in dictionary are unique
#add a key that already exits = overwrite
person['age'] = 30
print(person)

#keys need to be immutable (primitive types - strings, floats, ints, boolean, ets..) 
#lists and dictionaries cannot be keys, because they are mutable (can be changed through append, pop, insert, etc.)

#values in dictionaries can be anything
person_hobby = 'Skiing'
person['hobby'] = person_hobby
print(person)

#store name, age, and address of each person in the class
class_list = []
#class_list.append(person)
class_list.append({'name': 'P', 'age': '24', 'address': 'Toronto'})

print(class_list)
print(class_list[0])

#add the rest of the names to the class list
#['P', 'E', 'Sa', 'El', 'So', 'Pr']
#info on six people six dictionaries

#class_list.append({'name': 'P', 'age': '24', 'address': 'Toronto' })
class_list.append({'name': 'E',
                   'age': '25',
                   'address': 'Toronto',
                   'pet': {
                        'type': 'Dog',
                        'name': 'Billy',
                        'age': 2 
                   }})
class_list.append({'name': 'Sa', 'age': '26', 'address': 'Toronto' })
class_list.append({'name': 'El', 'age': '27', 'address': 'Toronto' })
class_list.append({'name': 'So', 'age': '28', 'address': 'Toronto' })
class_list.append({'name': 'Pr', 'age': '29', 'address': 'Toronto' })
print(class_list)
#print(class_list[1])


#print the age of the last person
last_person_in_list = class_list[-1] #-1 gets last item
print(last_person_in_list)

age_of_last = class_list[-1]['age'] # ***ANS***
print(age_of_last)
age_of_l = last_person_in_list['age']
print(age_of_l)

#print P's pets age

print(class_list[1]['pet']['name'])
# Out:
# {'name': 'John'}
# {'name': 'John', 'age': 27}
# {'name': 'John', 'age': 30}
# {'name': 'John', 'age': 30, 'hobby': 'Skiing'}
# [{'name': 'P', 'age': '24', 'address': 'Toronto'}]
# {'name': 'P', 'age': '24', 'address': 'Toronto'}
# [{'name': 'P', 'age': '24', 'address': 'Toronto'}, {'name': 'E', 'age': '25', 'address': 'Toronto', 'pet': {'type': 'Dog', 'name': 'Billy', 'age': 2}}, {'name': 'Sa', 'age': '26', 'address': 'Toronto'}, {'name': 'El', 'age': '27', 'address': 'Toronto'}, {'name': 'So', 'age': '28', 'address': 'Toronto'}, {'name': 'Pr', 'age': '29', 'address': 'Toronto'}]
# {'name': 'E', 'age': '25', 'address': 'Toronto', 'pet': {'type': 'Dog', 'name': 'Billy', 'age': 2}}
# {'name': 'Pr', 'age': '29', 'address': 'Toronto'}
# 29
# 29
# Billy
